# %% [markdown]
# <a href="https://colab.research.google.com/github/EnayathShaik/AI_ML/blob/main/Diabetes_Prediction_Using_NN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Diabetes Prediction

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras
from keras import Sequential
from keras.layers import Dense

# %%
df_diabetes = pd.read_csv('/content/diabetes.csv')
df_diabetes.shape
# Out:
# (768, 9)

# %%
df_diabetes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %%
assert df_diabetes.isnull().sum().sum() == 0, "Dataset contains null values"

# %%
df_diabetes.head(10)
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
# 5            5      116             74              0        0  25.6
# 6            3       78             50             32       88  31.0
# 7           10      115              0              0        0  35.3
# 8            2      197             70             45      543  30.5
# 9            8      125             96              0        0   0.0
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1
# 5                     0.201   30        0
# 6                     0.248   26        1
# 7                     0.134   29        0
# 8                     0.158   53        1
# 9                     0.232   54        1

# %%
df_diabetes.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# min      0.000000                  0.078000   21.000000    0.000000
# 25%     27.300000                  0.243750   24.000000    0.000000
# 50%     32.000000                  0.372500   29.000000    0.000000
# 75%     36.600000                  0.626250   41.000000    1.000000
# max     67.100000                  2.420000   81.000000    1.000000

# %%
df_diabetes['Glucose'] = np.where(df_diabetes['Glucose']==0, df_diabetes['Glucose'].median(), df_diabetes['Glucose'])

# %%
df_diabetes['Glucose'].describe()
# Out:
# count    768.000000
# mean     121.656250
# std       30.438286
# min       44.000000
# 25%       99.750000
# 50%      117.000000
# 75%      140.250000
# max      199.000000
# Name: Glucose, dtype: float64

# %%
df_diabetes['BloodPressure'] = np.where(df_diabetes['BloodPressure']==0, df_diabetes['BloodPressure'].median(), df_diabetes['BloodPressure'])
df_diabetes['SkinThickness'] = np.where(df_diabetes['SkinThickness']==0, df_diabetes['SkinThickness'].median(), df_diabetes['SkinThickness'])
df_diabetes['Insulin'] = np.where(df_diabetes['Insulin']==0, df_diabetes['Insulin'].median(), df_diabetes['Insulin'])
df_diabetes['BMI'] = np.where(df_diabetes['BMI']==0, df_diabetes['BMI'].median(), df_diabetes['BMI'])

# %%
df_diabetes.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  121.656250      72.386719      27.334635   94.652344
# std       3.369578   30.438286      12.096642       9.229014  105.547598
# min       0.000000   44.000000      24.000000       7.000000   14.000000
# 25%       1.000000   99.750000      64.000000      23.000000   30.500000
# 50%       3.000000  117.000000      72.000000      23.000000   31.250000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    32.450911                  0.471876   33.240885    0.348958
# std      6.875366                  0.331329   11.760232    0.476951
# min     18.200000                  0.078000   21.000000    0.000000
# 25%     27.500000                  0.243750   24.000000    0.000000
# 50%     32.000000                  0.372500   29.000000    0.000000
# 75%     36.600000                  0.626250   41.000000    1.000000
# max     67.100000                  2.420000   81.000000    1.000000

# %% [markdown]
# ## Check duplicate rows

# %%
df_diabetes.duplicated().sum()
# Out:
# np.int64(0)

# %%
x = df_diabetes.iloc[:, :-1]
y = df_diabetes.iloc[:, -1]

# %%
x.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6    148.0           72.0           35.0     30.5  33.6
# 1            1     85.0           66.0           29.0     30.5  26.6
# 2            8    183.0           64.0           23.0     30.5  23.3
# 3            1     89.0           66.0           23.0     94.0  28.1
# 4            0    137.0           40.0           35.0    168.0  43.1
#
#    DiabetesPedigreeFunction  Age
# 0                     0.627   50
# 1                     0.351   31
# 2                     0.672   32
# 3                     0.167   21
# 4                     2.288   33

# %%
y.head()
# Out:
# 0    1
# 1    0
# 2    1
# 3    0
# 4    1
# Name: Outcome, dtype: int64

# %%
print(x.shape, y.shape)
# Out:
# (768, 8) (768,)

# %% [markdown]
# ## Class Imbalance Verification

# %%
y.value_counts()/len(y)*100
# Out:
# Outcome
# 0    65.104167
# 1    34.895833
# Name: count, dtype: float64

# %%
x = df_diabetes.iloc[:, :-1]
y = df_diabetes.iloc[:, -1]

print(x.shape, y.shape)
# Out:
# (768, 8) (768,)

# %%
x.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6    148.0           72.0           35.0     30.5  33.6
# 1            1     85.0           66.0           29.0     30.5  26.6
# 2            8    183.0           64.0           23.0     30.5  23.3
# 3            1     89.0           66.0           23.0     94.0  28.1
# 4            0    137.0           40.0           35.0    168.0  43.1
#
#    DiabetesPedigreeFunction  Age
# 0                     0.627   50
# 1                     0.351   31
# 2                     0.672   32
# 3                     0.167   21
# 4                     2.288   33

# %%
y.head()
# Out:
# 0    1
# 1    0
# 2    1
# 3    0
# 4    1
# Name: Outcome, dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size=.2, stratify=y)

# %%
print(x_train.shape, y_train.shape)
print(x_test.shape, y_test.shape)
# Out:
# (614, 8) (614,)
# (154, 8) (154,)

# %%
from sklearn.preprocessing import StandardScaler

# %%
sc = StandardScaler()

# %%
x_train_sc = sc.fit_transform(x_train)
x_test_sc = sc.transform(x_test)

# %%
x_train_sc
# Out:
# array([[ 0.03767731, -0.89969208, -0.60828101, ..., -1.14296235,
#         -0.9838162 , -1.04408585],
#        [ 0.92744143, -0.24076569, -0.69124071, ..., -0.74866353,
#          0.8149258 ,  0.08746788],
#        [-0.85208682,  0.0886975 ,  0.13835623, ..., -0.69024889,
#         -1.13165801, -0.26070249],
#        ...,
#        [-0.55549878, -0.73496048, -1.68675703, ..., -1.15756601,
#          0.52232222, -1.04408585],
#        [ 0.63085339, -0.33960465, -0.69124071, ...,  0.24438535,
#         -0.63885198, -0.78295806],
#        [ 0.63085339,  0.41816069,  0.63611439, ...,  1.99682456,
#         -0.70661281,  1.13197902]])

# %%
x_test_sc
# Out:
# array([[-0.85208682, -0.0760341 , -1.52083764, ..., -1.49345019,
#         -0.80825406, -0.78295806],
#        [-0.55549878,  1.73601347,  1.29979195, ...,  1.74856234,
#          0.55004256, -0.78295806],
#        [ 1.81720556, -0.66906784,  1.13387256, ...,  1.9092026 ,
#          2.05926102,  0.43563826],
#        ...,
#        [-0.85208682, -0.9326384 , -1.35491826, ..., -1.46424287,
#         -0.15528607, -0.95704325],
#        [ 0.92744143, -0.63612152,  0.13835623, ...,  0.68249515,
#         -0.81133409,  1.04493643],
#        [ 0.03767731, -0.10898041, -0.19348254, ...,  1.74856234,
#          1.34469228, -0.60887287]])

# %%
from keras.layers import Dropout, BatchNormalization

# %%
import time

# %%
model = Sequential()
model.add(Dense(32, activation='relu', input_dim = 8))
model.add(BatchNormalization())
model.add(Dropout(rate=.25))
model.add(Dense(16, activation = 'relu'))
model.add(Dropout(rate=.2))
model.add(Dense(1, activation='sigmoid'))
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 32)             │           288 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 32)             │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 32)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 16)             │           528 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 16)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 1)              │            17 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 961 (3.75 KB)
#  Trainable params: 897 (3.50 KB)
#  Non-trainable params: 64 (256.00 B)

# %%
(32*8) + 32
# Out:
# 288

# %%
model.compile(loss= 'binary_crossentropy', metrics=['accuracy'])

# %%
start = time.time()
model.fit(x_train_sc, y_train, batch_size= 32, epochs=10, validation_data= (x_test_sc, y_test))
end = time.time()
print(f"Time Taken:{end-start}")
# Out:
# Epoch 1/10
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.5641 - loss: 0.7710 - val_accuracy: 0.6234 - val_loss: 0.6648
# Epoch 2/10
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6775 - loss: 0.6395 - val_accuracy: 0.7338 - val_loss: 0.6184
# Epoch 3/10
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7032 - loss: 0.6205 - val_accuracy: 0.7338 - val_loss: 0.5854
# Epoch 4/10
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6981 - loss: 0.6204 - val_accuracy: 0.7532 - val_loss: 0.5552
# Epoch 5/10
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7422 - loss: 0.5255 - val_accuracy: 0.7792 - val_loss: 0.5335
# Epoch 6/10
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7099 - loss: 0.5444 - val_accuracy: 0.7792 - val_loss: 0.5151
# Epoch 7/10
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7394 - loss: 0.5523 - val_accuracy: 0.7792 - val_loss: 0.5036
# Epoch 8/10
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7304 - loss: 0.5598 - val_accuracy: 0.7727 - val_loss: 0.4947
# Epoch 9/10
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7595 - loss: 0.5016 - val_accuracy: 0.7792 - val_loss: 0.4890
# Epoch 10/10
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7234 - loss: 0.5097 - val_accuracy: 0.7727 - val_loss: 0.4834
# Time Taken:3.77128005027771

# %%
model_1 = Sequential()
model_1.add(Dense(32, activation='relu', input_dim = 8))
model_1.add(BatchNormalization())
model_1.add(Dropout(rate=.25))
model_1.add(Dense(16, activation = 'relu'))
model_1.add(Dropout(rate=.2))
model_1.add(Dense(1, activation='sigmoid'))

# %%
model_1.compile(loss= 'binary_crossentropy', metrics=['accuracy'])

# %%
start = time.time()
model_1.fit(x_train_sc, y_train, batch_size= 1, epochs=10, validation_data= (x_test_sc, y_test))
end = time.time()
print(f"Time Taken:{end-start}")
# Out:
# Epoch 1/10
# 614/614 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.6597 - loss: 0.6867 - val_accuracy: 0.6234 - val_loss: 3.5464
# Epoch 2/10
# 614/614 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.6370 - loss: 0.6709 - val_accuracy: 0.6104 - val_loss: 6.1666
# Epoch 3/10
# 614/614 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.6237 - loss: 0.6662 - val_accuracy: 0.5974 - val_loss: 5.8894
# Epoch 4/10
# 614/614 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.6528 - loss: 0.6516 - val_accuracy: 0.6169 - val_loss: 5.6735
# Epoch 5/10
# 614/614 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.6597 - loss: 0.6454 - val_accuracy: 0.6104 - val_loss: 5.8661
# Epoch 6/10
# 614/614 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.6537 - loss: 0.6467 - val_accuracy: 0.5909 - val_loss: 6.2243
# Epoch 7/10
# 614/614 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.6322 - loss: 0.6577 - val_accuracy: 0.6169 - val_loss: 5.9807
# Epoch 8/10
# 614/614 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.6723 - loss: 0.6343 - val_accuracy: 0.6039 - val_loss: 5.9260
# Epoch 9/10
# 614/614 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.6453 - loss: 0.6506 - val_accuracy: 0.6169 - val_loss: 5.9601
# Epoch 10/10
# 614/614 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.6402 - loss: 0.6539 - val_accuracy: 0.6104 - val_loss: 5.8289
# Time Taken:22.5672926902771

# %%
df_diabetes.head(10)
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6    148.0           72.0           35.0     30.5  33.6
# 1            1     85.0           66.0           29.0     30.5  26.6
# 2            8    183.0           64.0           23.0     30.5  23.3
# 3            1     89.0           66.0           23.0     94.0  28.1
# 4            0    137.0           40.0           35.0    168.0  43.1
# 5            5    116.0           74.0           23.0     30.5  25.6
# 6            3     78.0           50.0           32.0     88.0  31.0
# 7           10    115.0           72.0           23.0     30.5  35.3
# 8            2    197.0           70.0           45.0    543.0  30.5
# 9            8    125.0           96.0           23.0     30.5  32.0
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1
# 5                     0.201   30        0
# 6                     0.248   26        1
# 7                     0.134   29        0
# 8                     0.158   53        1
# 9                     0.232   54        1

# %%
pred_data = pd.DataFrame({"Pregnancies": [1],	"Glucose": [100],	"BloodPressure": [80],"SkinThickness": [29] ,
                          "Insulin":[120],"BMI":[36.2],"DiabetesPedigreeFunction": [0.56],"Age":[80]})

# %%
pred_data.shape
# Out:
# (1, 8)

# %%
#pred_data_sc = sc.transform(pred_data)

# %%
#res = model.predict(pred_data_sc)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step

# %%
#res
# Out:
# array([[0.34851396]], dtype=float32)

# %%
def pred_result(x_input):
  x_input_sc = sc.transform(x_input)
  res = model.predict(x_input_sc)
  res = [1 if res > 0.5 else 0]
  return res

# %%
result = pred_result(pred_data)
print(result)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# [0]

# %%
pred_data_2 = pd.DataFrame({"Pregnancies": [10],	"Glucose": [120],	"BloodPressure": [20],"SkinThickness": [22] ,
                          "Insulin":[30.6],"BMI":[32],"DiabetesPedigreeFunction": [0.22],"Age":[55]})
#pred_data_sc_2 = sc.transform(pred_data_2)
#res = model.predict(pred_data_sc_2)
#print(res)
result = pred_result(pred_data_2)
print(result)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# [1]

# %%
pred_data_3 = pd.DataFrame({"Pregnancies": [10],	"Glucose": [120],	"BloodPressure": [20],"SkinThickness": [22] ,
                          "Insulin":[30.6],"BMI":[29],"DiabetesPedigreeFunction": [0.22],"Age":[60]})
result = pred_result(pred_data_3)
print(result)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# [1]
