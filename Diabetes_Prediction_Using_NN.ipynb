# %% [markdown]
# <a href="https://colab.research.google.com/github/EnayathShaik/AI_ML/blob/Practice/Diabetes_Prediction_Using_NN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Diabetes Prediction

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras
from keras import Sequential
from keras.layers import Dense

# %%
df_diabetes = pd.read_csv('/content/diabetes.csv')
df_diabetes.shape
# Out:
# (768, 9)

# %%
df_diabetes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %%
assert df_diabetes.isnull().sum().sum() == 0, "Dataset contains null values"

# %%
df_diabetes.head(10)
# Out:
#    Pregnancies  Glucose  BloodPressure  ...  DiabetesPedigreeFunction  Age  Outcome
# 0            6      148             72  ...                     0.627   50        1
# 1            1       85             66  ...                     0.351   31        0
# 2            8      183             64  ...                     0.672   32        1
# 3            1       89             66  ...                     0.167   21        0
# 4            0      137             40  ...                     2.288   33        1
# 5            5      116             74  ...                     0.201   30        0
# 6            3       78             50  ...                     0.248   26        1
# 7           10      115              0  ...                     0.134   29        0
# 8            2      197             70  ...                     0.158   53        1
# 9            8      125             96  ...                     0.232   54        1
#
# [10 rows x 9 columns]

# %%
df_diabetes.describe()
# Out:
#        Pregnancies     Glucose  ...         Age     Outcome
# count   768.000000  768.000000  ...  768.000000  768.000000
# mean      3.845052  120.894531  ...   33.240885    0.348958
# std       3.369578   31.972618  ...   11.760232    0.476951
# min       0.000000    0.000000  ...   21.000000    0.000000
# 25%       1.000000   99.000000  ...   24.000000    0.000000
# 50%       3.000000  117.000000  ...   29.000000    0.000000
# 75%       6.000000  140.250000  ...   41.000000    1.000000
# max      17.000000  199.000000  ...   81.000000    1.000000
#
# [8 rows x 9 columns]

# %%
df_diabetes['Glucose'] = np.where(df_diabetes['Glucose']==0, df_diabetes['Glucose'].median(), df_diabetes['Glucose'])

# %%
df_diabetes['Glucose'].describe()
# Out:
# count    768.000000
# mean     121.656250
# std       30.438286
# min       44.000000
# 25%       99.750000
# 50%      117.000000
# 75%      140.250000
# max      199.000000
# Name: Glucose, dtype: float64

# %%
df_diabetes['BloodPressure'] = np.where(df_diabetes['BloodPressure']==0, df_diabetes['BloodPressure'].median(), df_diabetes['BloodPressure'])
df_diabetes['SkinThickness'] = np.where(df_diabetes['SkinThickness']==0, df_diabetes['SkinThickness'].median(), df_diabetes['SkinThickness'])
df_diabetes['Insulin'] = np.where(df_diabetes['Insulin']==0, df_diabetes['Insulin'].median(), df_diabetes['Insulin'])
df_diabetes['BMI'] = np.where(df_diabetes['BMI']==0, df_diabetes['BMI'].median(), df_diabetes['BMI'])

# %%
df_diabetes.describe()
# Out:
#        Pregnancies     Glucose  ...         Age     Outcome
# count   768.000000  768.000000  ...  768.000000  768.000000
# mean      3.845052  121.656250  ...   33.240885    0.348958
# std       3.369578   30.438286  ...   11.760232    0.476951
# min       0.000000   44.000000  ...   21.000000    0.000000
# 25%       1.000000   99.750000  ...   24.000000    0.000000
# 50%       3.000000  117.000000  ...   29.000000    0.000000
# 75%       6.000000  140.250000  ...   41.000000    1.000000
# max      17.000000  199.000000  ...   81.000000    1.000000
#
# [8 rows x 9 columns]

# %% [markdown]
# ## Check duplicate rows

# %%
df_diabetes.duplicated().sum()
# Out:
# np.int64(0)

# %%
x = df_diabetes.iloc[:, :-1]
y = df_diabetes.iloc[:, -1]

# %%
x.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  ...   BMI  DiabetesPedigreeFunction  Age
# 0            6    148.0           72.0  ...  33.6                     0.627   50
# 1            1     85.0           66.0  ...  26.6                     0.351   31
# 2            8    183.0           64.0  ...  23.3                     0.672   32
# 3            1     89.0           66.0  ...  28.1                     0.167   21
# 4            0    137.0           40.0  ...  43.1                     2.288   33
#
# [5 rows x 8 columns]

# %%
y.head()
# Out:
# 0    1
# 1    0
# 2    1
# 3    0
# 4    1
# Name: Outcome, dtype: int64

# %%
print(x.shape, y.shape)
# Out:
# (768, 8) (768,)

# %% [markdown]
# ## Class Imbalance Verification

# %%
y.value_counts()/len(y)*100
# Out:
# Outcome
# 0    65.104167
# 1    34.895833
# Name: count, dtype: float64

# %%
x = df_diabetes.iloc[:, :-1]
y = df_diabetes.iloc[:, -1]

print(x.shape, y.shape)
# Out:
# (768, 8) (768,)

# %%
x.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  ...   BMI  DiabetesPedigreeFunction  Age
# 0            6    148.0           72.0  ...  33.6                     0.627   50
# 1            1     85.0           66.0  ...  26.6                     0.351   31
# 2            8    183.0           64.0  ...  23.3                     0.672   32
# 3            1     89.0           66.0  ...  28.1                     0.167   21
# 4            0    137.0           40.0  ...  43.1                     2.288   33
#
# [5 rows x 8 columns]

# %%
y.head()
# Out:
# 0    1
# 1    0
# 2    1
# 3    0
# 4    1
# Name: Outcome, dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size=.2, stratify=y)

# %%
print(x_train.shape, y_train.shape)
print(x_test.shape, y_test.shape)
# Out:
# (614, 8) (614,)
# (154, 8) (154,)

# %%
from sklearn.preprocessing import StandardScaler

# %%
sc = StandardScaler()

# %%
x_train_sc = sc.fit_transform(x_train)
x_test_sc = sc.transform(x_test)

# %%
x_train_sc
# Out:
# array([[-1.13248424, -0.79311329,  0.78831748, ..., -1.04354183,
#         -0.52497906, -0.95980874],
#        [-0.25081223,  1.57760522, -0.04420218, ...,  0.15412073,
#         -0.81712311, -0.79157506],
#        [-1.13248424, -0.27350376,  0.62181355, ...,  1.7657901 ,
#         -0.91060921, -0.53922455],
#        ...,
#        [ 0.63085978, -1.15034485,  0.62181355, ..., -1.33926098,
#         -1.15308877, -0.11864036],
#        [-0.5447029 , -0.46835733,  0.62181355, ..., -0.77739459,
#         -0.64183668,  1.56369639],
#        [-1.13248424, -0.59825972, -0.71021792, ..., -0.65910693,
#         -0.07215577, -0.8756919 ]])

# %%
x_test_sc
# Out:
# array([[ 4.30784370e-02, -4.03406142e-01,  1.62083715e+00, ...,
#          7.89916902e-01, -8.40494637e-01, -2.86874036e-01],
#        [-8.38593573e-01, -1.47510081e+00, -1.37623365e+00, ...,
#          1.54120730e-01,  2.25623233e+00, -7.91575062e-01],
#        [-8.38593573e-01, -3.70930546e-01, -8.76721851e-01, ...,
#         -1.22097332e+00, -9.95330985e-01, -8.75691900e-01],
#        ...,
#        [ 6.30859777e-01,  3.76008163e-01, -2.10706117e-01, ...,
#          4.64625837e-01,  1.84930993e-01, -3.70990874e-01],
#        [ 4.30784370e-02,  1.57760522e+00, -4.42021842e-02, ...,
#          1.67707435e+00,  8.80238599e-04, -6.23341387e-01],
#        [-2.50812233e-01,  1.64255641e+00,  9.54821415e-01, ...,
#          5.08983709e-01, -6.44758120e-01, -9.59808738e-01]])

# %%
from keras.layers import Dropout, BatchNormalization

# %%
import time

# %%
model = Sequential()
model.add(Dense(32, activation='relu', input_dim = 8))
model.add(BatchNormalization())
model.add(Dropout(rate=.25))
model.add(Dense(16, activation = 'relu'))
model.add(Dropout(rate=.2))
model.add(Dense(1, activation='sigmoid'))
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_1 (Dense)                 │ (None, 32)             │           288 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 32)             │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 32)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 16)             │           528 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 16)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 1)              │            17 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 961 (3.75 KB)
#  Trainable params: 897 (3.50 KB)
#  Non-trainable params: 64 (256.00 B)

# %%
(32*8) + 32
# Out:
# 288

# %%
model.compile(loss= 'binary_crossentropy', metrics=['accuracy'])

# %%
start = time.time()
model.fit(x_train_sc, y_train, batch_size= 32, epochs=10, validation_data= (x_test_sc, y_test))
end = time.time()
print(f"Time Taken:{end-start}")
# Out:
# Epoch 1/10
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - accuracy: 0.6274 - loss: 0.7079 - val_accuracy: 0.6299 - val_loss: 0.6461
# Epoch 2/10
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.6872 - loss: 0.6145 - val_accuracy: 0.6688 - val_loss: 0.6231
# Epoch 3/10
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7520 - loss: 0.5469 - val_accuracy: 0.6948 - val_loss: 0.6039
# Epoch 4/10
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7069 - loss: 0.5697 - val_accuracy: 0.6818 - val_loss: 0.5864
# Epoch 5/10
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7510 - loss: 0.5112 - val_accuracy: 0.6623 - val_loss: 0.5703
# Epoch 6/10
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7531 - loss: 0.5147 - val_accuracy: 0.6688 - val_loss: 0.5587
# Epoch 7/10
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6977 - loss: 0.5851 - val_accuracy: 0.6753 - val_loss: 0.5499
# Epoch 8/10
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7303 - loss: 0.4941 - val_accuracy: 0.6883 - val_loss: 0.5442
# Epoch 9/10
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7810 - loss: 0.4627 - val_accuracy: 0.6818 - val_loss: 0.5400
# Epoch 10/10
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7489 - loss: 0.5049 - val_accuracy: 0.6883 - val_loss: 0.5346
# Time Taken:4.341057300567627

# %%
model_1 = Sequential()
model_1.add(Dense(32, activation='relu', input_dim = 8))
model_1.add(BatchNormalization())
model_1.add(Dropout(rate=.25))
model_1.add(Dense(16, activation = 'relu'))
model_1.add(Dropout(rate=.2))
model_1.add(Dense(1, activation='sigmoid'))
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model_1.compile(loss= 'binary_crossentropy', metrics=['accuracy'])

# %%
start = time.time()
model_1.fit(x_train_sc, y_train, batch_size= 1, epochs=10, validation_data= (x_test_sc, y_test))
end = time.time()
print(f"Time Taken:{end-start}")
# Out:
# Epoch 1/10
# 614/614 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.6327 - loss: 0.6866 - val_accuracy: 0.5779 - val_loss: 2.7607
# Epoch 2/10
# 614/614 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.6312 - loss: 0.6723 - val_accuracy: 0.5844 - val_loss: 4.6591
# Epoch 3/10
# 614/614 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.6653 - loss: 0.6536 - val_accuracy: 0.5779 - val_loss: 4.8291
# Epoch 4/10
# 614/614 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.6776 - loss: 0.6413 - val_accuracy: 0.5844 - val_loss: 4.6735
# Epoch 5/10
# 614/614 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.6132 - loss: 0.6672 - val_accuracy: 0.5844 - val_loss: 4.7408
# Epoch 6/10
# 614/614 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.6550 - loss: 0.6460 - val_accuracy: 0.5779 - val_loss: 4.7053
# Epoch 7/10
# 614/614 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.6536 - loss: 0.6458 - val_accuracy: 0.5779 - val_loss: 4.7435
# Epoch 8/10
# 614/614 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.6771 - loss: 0.6313 - val_accuracy: 0.5779 - val_loss: 4.8017
# Epoch 9/10
# 614/614 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.6658 - loss: 0.6378 - val_accuracy: 0.5779 - val_loss: 4.6676
# Epoch 10/10
# 614/614 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.6428 - loss: 0.6522 - val_accuracy: 0.5779 - val_loss: 4.8983
# Time Taken:21.77159833908081
